# %% [markdown]
# ## Marker

# %%
import matplotlib as mpl
from svgpathtools import svg2paths
from svgpath2mpl import parse_path
import matplotlib.pyplot as plt

#Any svg image
planet_path, attributes = svg2paths("C:/Users/pamel/Downloads/flag-solid.svg")

planet_marker = parse_path(attributes[0]['d'])

planet_marker.vertices -= planet_marker.vertices.mean(axis=0)

import numpy as np

x = np.linspace(0,2*np.pi,10)
y = np.sin(x)

planet_marker = planet_marker.transformed(mpl.transforms.Affine2D().rotate_deg(180))
planet_marker = planet_marker.transformed(mpl.transforms.Affine2D().scale(-1,1))

plt.plot(x,y,'o',marker=planet_marker,markersize=30)
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_18260\3992528096.py:20: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x,y,'o',marker=planet_marker,markersize=30)

# %% [markdown]
# ## Map

# %%
import cartopy.crs as ccrs

# Point locations
point_locations = {
    'Argentina': [ -15.793889,-47.882778],
    'Southern North Sea': [53.0, 3.0],
    'Central North Sea': [57.0, 2.0],
    'Northern North Sea': [61.0, 2.0],
    'West of Shetland': [60.5, -3.0],
    'Haltenbank': [64.0, 7.0],
    'Barents Sea': [72.0, 35.0],
    'Newfoundland offshore': [47.0, -55.0],
    'Nova Scotia offshore': [44.0, -62.0],
    'Canadian east coast deepwater': [45.0, -55.0],
    'Gulf of St. Lawrence': [48.0, -64.0],
    'Beaufort Sea': [72.0, -140.0],
    'Sakhalin east coast (52.5°N to 55°N)': [54.0, 143.0],
    'Sakhalin east coast (51°N to 52.5°N)': [51.75, 143.0],
    'Aniva Bay': [46.5, 141.0],
    'Tartar Strait': [51.5, 141.5],
    'northern_caspian': [47, 50],
    'central_caspian': [41, 52],
    'apsheron_ridge': [40.2, 50.5],
    'southern_caspian': [37, 53],
    'offshore_vietnam': [14, 109],
    'gulf_of_thailand_north': [11, 103],
    'offshore_peninsular_malaysia': [6, 103],
    'offshore_natuna_island': [4, 108],
    'sakhalin_east_coast': [54, 143],
    'borneo_sarawak_shallows': [3, 112],
    'borneo_sarawak_shelf_edge': [5, 112],
    'borneo_sabah_shallows': [6, 116],
    'borneo_sabah_shelf_edge': [7, 116],
    'borneo_sabah_deepwater': [7, 117],
    'nigeria_shallow': [4, 6],
    'nigeria_deep': [4, 5],
    'northern_angola': [-8, 12],
    'southern_namibia': [-28, 15]
}

plt.figure(figsize=(12, 8))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.stock_img()

# Plotting points on the map with transparency
for coordinates in point_locations.values():
    ax.plot(coordinates[1], coordinates[0], 'ro', marker=planet_marker, markersize=15, alpha=0.7, transform=ccrs.PlateCarree())

plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_18260\3675477039.py:48: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ro" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(coordinates[1], coordinates[0], 'ro', marker=planet_marker, markersize=15, alpha=0.7, transform=ccrs.PlateCarree())
