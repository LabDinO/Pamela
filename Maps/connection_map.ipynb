# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Carregando os dados dos contornos dos países
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Excluindo a Antártica
world = world[world['continent'] != 'Antarctica']

# Lista de países e suas coordenadas
country_centers = {
    'argentina': [-38.4161, -63.6167],
    'australia': [-25.2744, 133.7751],
    'austria': [47.5162, 14.5501],
    'brazil': [-14.2350, -51.9253],
    'canada': [56.1304, -106.3468],
    'chile' : [-33.447487, -70.673676],
    'china': [35.8617, 104.1954],
    'cuba' : [22.12300296778533, -79.40033150104198],
    'cyprus': [35.1264, 33.4299],
    'czech republic': [49.8175, 15.4729],
    'denmark': [56.2639, 9.5018],
    'france': [46.6034, 1.8883],
    'gabon' : [0.390100, 9.454400],
    'germany': [51.1657, 10.4515],
    'hong kong': [22.3193, 114.1694],
    'india': [20.5937, 78.9629],
    'indonesia': [-0.7893, 113.9213],
    'italy': [41.8719, 12.5674],
    'japan': [36.2048, 138.2529],
    'malaysia': [4.2105, 101.9758],
    'mexico': [23.6345, -102.5528],
    'netherlands': [52.1326, 5.2913],
    'new zealand': [-40.9006, 174.8860],
    'norway': [60.4720, 8.4689],
    'philippines': [12.8797, 121.7740],
    'portugal': [39.3999, -8.2245],
    'russia': [61.5240, 105.3188],
    'south africa': [-30.5595, 22.9375],
    'south korea': [35.9078, 127.7669],
    'spain': [40.4637, -3.7492],
    'sweden': [60.1282, 18.6435],
    'switzerland': [46.8182, 8.2275],
    'thailand': [15.8700, 100.9925],
    'turkey': [38.9637, 35.2433],
    'united kingdom': [55.3781, -3.4360],
    'united states of america': [37.0902, -95.7129],
    'uruguay': [-32.5228, -55.7658],
    'vietnam': [14.0583, 108.2772],
}

# Lista de conexões e suas forças de conexão
connections = {
    ('argentina', 'australia'): 1,
    ('argentina', 'brazil'): 3,
    ('argentina', 'canada'): 1,
    ('argentina', 'china'): 1,
    ('argentina', 'cyprus'): 1,
    ('argentina', 'czech republic'): 1,
    ('argentina', 'denmark'): 1,
    ('argentina', 'france'): 1,
    ('argentina', 'germany'): 3,
    ('argentina', 'italy'): 2,
    ('argentina', 'malaysia'): 1,
    ('argentina', 'mexico'): 1,
    ('argentina', 'norway'): 1,
    ('argentina', 'south africa'): 1,
    ('argentina', 'spain'): 2,
    ('argentina', 'sweden'): 1,
    ('argentina', 'turkey'): 1,
    ('argentina', 'united states of america'): 2,
    ('argentina', 'uruguay'): 2,
    ('australia', 'austria'): 1,
    ('australia', 'brazil'): 4,
    ('australia', 'canada'): 6,
    ('australia', 'china'): 2,
    ('australia', 'cyprus'): 1,
    ('australia', 'denmark'): 1,
    ('australia', 'france'): 1,
    ('australia', 'germany'): 3,
    ('australia', 'hong kong'): 1,
    ('australia', 'india'): 2,
    ('australia', 'italy'): 4,
    ('australia', 'japan'): 3,
    ('australia', 'malaysia'): 2,
    ('australia', 'mexico'): 2,
    ('australia', 'netherlands'): 3,
    ('australia', 'new zealand'): 2,
    ('australia', 'norway'): 2,
    ('australia', 'philippines'): 1,
    ('australia', 'russia'): 1,
    ('australia', 'south africa'): 1,
    ('australia', 'spain'): 3,
    ('australia', 'sweden'): 1,
    ('australia', 'thailand'): 1,
    ('australia', 'turkey'): 1,
    ('australia', 'united kingdom'): 5,
    ('australia', 'united states of america'): 7,
    ('australia', 'vietnam'): 1,
    ('austria', 'brazil'): 1,
    ('austria', 'china'): 1,
    ('austria', 'germany'): 1,
    ('austria', 'hong kong'): 1,
    ('austria', 'italy'): 1,
    ('austria', 'mexico'): 1,
    ('austria', 'united states of america'): 1,
    ('brazil', 'canada'): 2,
    ('brazil', 'chile'): 1,
    ('brazil', 'china'): 2,
    ('brazil', 'cyprus'): 1,
    ('brazil', 'czech republic'): 1,
    ('brazil', 'denmark'): 1,
    ('brazil', 'france'): 2,
    ('brazil', 'germany'): 4,
    ('brazil', 'hong kong'): 1,
    ('brazil', 'italy'): 7,
    ('brazil', 'malaysia'): 1,
    ('brazil', 'mexico'): 3,
    ('brazil', 'new zealand'): 1,
    ('brazil', 'norway'): 1,
    ('brazil', 'philippines'): 1,
    ('brazil', 'portugal'): 4,
    ('brazil', 'south africa'): 1,
    ('brazil', 'spain'): 5,
    ('brazil', 'sweden'): 1,
    ('brazil', 'switzerland'): 1,
    ('brazil', 'turkey'): 1,
    ('brazil', 'united kingdom'): 2,
    ('brazil', 'united states of america'): 11,
    ('brazil', 'uruguay'): 2,
    ('canada', 'china'): 2,
    ('canada', 'cyprus'): 1,
    ('canada', 'denmark'): 1,
    ('canada', 'france'): 1,
    ('canada', 'germany'): 2,
    ('canada', 'india'): 2,
    ('canada', 'italy'): 3,
    ('canada', 'japan'): 2,
    ('canada', 'malaysia'): 1,
    ('canada', 'mexico'): 1,
    ('canada', 'netherlands'): 2,
    ('canada', 'new zealand'): 2,
    ('canada', 'norway'): 2,
    ('canada', 'russia'): 1,
    ('canada', 'south africa'): 1,
    ('canada', 'south korea'): 2,
    ('canada', 'spain'): 3,
    ('canada', 'sweden'): 1,
    ('canada', 'turkey'): 1,
    ('canada', 'united kingdom'): 5,
    ('canada', 'united states of america'): 7,
    ('chile', 'italy'): 1,
    ('chile', 'switzerland'): 1,
    ('china', 'cyprus'): 1,
    ('china', 'denmark'): 1,
    ('china', 'france'): 1,
    ('china', 'germany'): 2,
    ('china', 'hong kong'): 1,
    ('china', 'italy'): 2,
    ('china', 'malaysia'): 1,
    ('china', 'mexico'): 2,
    ('china', 'norway'): 1,
    ('china', 'south africa'): 1,
    ('china', 'sweden'): 1,
    ('china', 'turkey'): 1,
    ('china', 'united states of america'): 2,
    ('cuba', 'spain'): 1,
    ('cuba', 'united states of america'): 1,
    ('cyprus', 'denmark'): 1,
    ('cyprus', 'france'): 1,
    ('cyprus', 'germany'): 1,
    ('cyprus', 'italy'): 1,
    ('cyprus', 'malaysia'): 1,
    ('cyprus', 'mexico'): 1,
    ('cyprus', 'norway'): 1,
    ('cyprus', 'south africa'): 1,
    ('cyprus', 'sweden'): 1,
    ('cyprus', 'turkey'): 1,
    ('cyprus', 'united states of america'): 1,
    ('czech republic', 'italy'): 1,
    ('czech republic', 'spain'): 1,
    ('czech republic', 'uruguay'): 1,
    ('denmark', 'france'): 1,
    ('denmark', 'germany'): 1,
    ('denmark', 'italy'): 1,
    ('denmark', 'malaysia'): 1,
    ('denmark', 'mexico'): 1,
    ('denmark', 'norway'): 1,
    ('denmark', 'south africa'): 1,
    ('denmark', 'sweden'): 1,
    ('denmark', 'turkey'): 1,
    ('denmark', 'united states of america'): 1,
    ('france', 'germany'): 1,
    ('france', 'italy'): 1,
    ('france', 'malaysia'): 1,
    ('france', 'mexico'): 1,
    ('france', 'netherlands'): 4,
    ('france', 'norway'): 5,
    ('france', 'south africa'): 1,
    ('france', 'sweden'): 1,
    ('france', 'turkey'): 1,
    ('france', 'united kingdom'): 4,
    ('france', 'united states of america'): 5,
    ('gabon', 'germany'): 1,
    ('gabon', 'united kingdom'): 1,
    ('gabon', 'united states of america'): 1,
    ('germany', 'hong kong'): 1,
    ('germany', 'italy'): 3,
    ('germany', 'japan'): 1,
    ('germany', 'malaysia'): 1,
    ('germany', 'mexico'): 2,
    ('germany', 'netherlands'): 1,
    ('germany', 'norway'): 1,
    ('germany', 'south africa'): 1,
    ('germany', 'spain'): 1,
    ('germany', 'sweden'): 1,
    ('germany', 'turkey'): 1,
    ('germany', 'united kingdom'): 2,
    ('germany', 'united states of america'): 5,
    ('germany', 'uruguay'): 1,
    ('hong kong', 'italy'): 1,
    ('hong kong', 'mexico'): 1,
    ('hong kong', 'united states of america'): 1,
    ('india', 'new zealand'): 1,
    ('india', 'south korea'): 3,
    ('indonesia', 'japan'): 1,
    ('indonesia', 'malaysia'): 1,
    ('indonesia', 'philippines'): 1,
    ('indonesia', 'thailand'): 1,
    ('indonesia', 'vietnam'): 1,
    ('italy', 'japan'): 2,
    ('italy', 'malaysia'): 1,
    ('italy', 'mexico'): 3,
    ('italy', 'netherlands'): 2,
    ('italy', 'new zealand'): 1,
    ('italy', 'norway'): 2,
    ('italy', 'russia'): 1,
    ('italy', 'south africa'): 1,
    ('italy', 'spain'): 2,
    ('italy', 'sweden'): 1,
    ('italy', 'switzerland'): 1,
    ('italy', 'turkey'): 1,
    ('italy', 'united kingdom'): 2,
    ('italy', 'united states of america'): 5,
    ('italy', 'uruguay'): 1,
    ('japan', 'malaysia'): 1,
    ('japan', 'netherlands'): 2,
    ('japan', 'new zealand'): 1,
    ('japan', 'norway'): 1,
    ('japan', 'philippines'): 1,
    ('japan', 'russia'): 1,
    ('japan', 'spain'): 1,
    ('japan', 'thailand'): 1,
    ('japan', 'united kingdom'): 3,
    ('japan', 'united states of america'): 2,
    ('japan', 'vietnam'): 1,
    ('malaysia', 'mexico'): 1,
    ('malaysia', 'norway'): 1,
    ('malaysia', 'philippines'): 1,
    ('malaysia', 'south africa'): 1,
    ('malaysia', 'sweden'): 1,
    ('malaysia', 'thailand'): 1,
    ('malaysia', 'turkey'): 1,
    ('malaysia', 'united states of america'): 1,
    ('malaysia', 'vietnam'): 1,
    ('mexico', 'norway'): 1,
    ('mexico', 'south africa'): 1,
    ('mexico', 'sweden'): 1,
    ('mexico', 'turkey'): 1,
    ('mexico', 'united states of america'): 2,
    ('netherlands', 'new zealand'): 1,
    ('netherlands', 'norway'): 2,
    ('netherlands', 'russia'): 1,
    ('netherlands', 'spain'): 1,
    ('netherlands', 'united kingdom'): 4,
    ('netherlands', 'united states of america'): 3,
    ('new zealand', 'norway'): 1,
    ('new zealand', 'russia'): 1,
    ('new zealand', 'south korea'): 1,
    ('new zealand', 'spain'): 1,
    ('new zealand', 'united kingdom'): 2,
    ('new zealand', 'united states of america'): 2,
    ('norway', 'russia'): 1,
    ('norway', 'south africa'): 1,
    ('norway', 'sweden'): 1,
    ('norway', 'turkey'): 1,
    ('norway', 'united kingdom'): 3,
    ('norway', 'united states of america'): 3,
    ('philippines', 'thailand'): 1,
    ('philippines', 'vietnam'): 1,
    ('portugal', 'united kingdom'): 1,
    ('portugal', 'united states of america'): 3,
    ('russia', 'united kingdom'): 1,
    ('russia', 'united states of america'): 1,
    ('south africa', 'sweden'): 1,
    ('south africa', 'turkey'): 1,
    ('south africa', 'united states of america'): 2,
    ('spain', 'united kingdom'): 4,
    ('spain', 'united states of america'): 9,
    ('spain', 'uruguay'): 1,
    ('sweden', 'turkey'): 1,
    ('sweden', 'united states of america'): 1,
    ('thailand', 'vietnam'): 1,
    ('turkey', 'united states of america'): 1,
    ('united kingdom', 'united states of america'): 8
}

# Criando um plot
fig, ax = plt.subplots(figsize=(30, 20))
plt.axis('off')
# Plotando os contornos dos países
world.boundary.plot(ax=ax, linewidth=0.5, color='black')

# Mapeando conexões a cores
connection_colors = {
    ('argentina', 'australia'): 'blue',
    ('argentina', 'brazil'): 'blue',
    ('argentina', 'canada'): 'blue',
    ('argentina', 'china'): 'blue',
    ('argentina', 'cyprus'): 'blue',
    ('argentina', 'czech republic'): 'blue',
    ('argentina', 'denmark'): 'blue',
    ('argentina', 'france'): 'blue',
    ('argentina', 'germany'): 'blue',
    ('argentina', 'italy'): 'blue',
    ('argentina', 'malaysia'): 'blue',
    ('argentina', 'mexico'): 'blue',
    ('argentina', 'norway'): 'blue',
    ('argentina', 'south africa'): 'blue',
    ('argentina', 'spain'): 'blue',
    ('argentina', 'sweden'): 'blue',
    ('argentina', 'turkey'): 'blue',
    ('argentina', 'united states of america'): 'blue',
    ('argentina', 'uruguay'): 'blue',
    ('australia', 'austria'): 'red',
    ('australia', 'brazil'): 'red',
    ('australia', 'canada'): 'red',
    ('australia', 'china'): 'red',
    ('australia', 'cyprus'): 'red',
    ('australia', 'denmark'): 'red',
    ('australia', 'france'): 'red',
    ('australia', 'germany'): 'red',
    ('australia', 'hong kong'): 'red',
    ('australia', 'india'): 'red',
    ('australia', 'italy'): 'red',
    ('australia', 'japan'): 'red',
    ('australia', 'malaysia'): 'red',
    ('australia', 'mexico'): 'red',
    ('australia', 'netherlands'): 'red',
    ('australia', 'new zealand'): 'red',
    ('australia', 'norway'): 'red',
    ('australia', 'philippines'): 'red',
    ('australia', 'russia'): 'red',
    ('australia', 'south africa'): 'red',
    ('australia', 'spain'): 'red',
    ('australia', 'sweden'): 'red',
    ('australia', 'thailand'): 'red',
    ('australia', 'turkey'): 'red',
    ('australia', 'united kingdom'): 'red',
    ('australia', 'united states of america'): 'red',
    ('australia', 'vietnam'): 'red',
    ('austria', 'brazil'): 'red',
    ('austria', 'china'): 'red',
    ('austria', 'germany'): 'red',
    ('austria', 'hong kong'): 'red',
    ('austria', 'italy'): 'red',
    ('austria', 'mexico'): 'red',
    ('austria', 'united states of america'): 'red',
    ('brazil', 'canada'): 'blue',
    ('brazil', 'chile'): 'blue',
    ('brazil', 'china'): 'blue',
    ('brazil', 'cyprus'): 'blue',
    ('brazil', 'czech republic'): 'blue',
    ('brazil', 'denmark'): 'blue',
    ('brazil', 'france'): 'blue',
    ('brazil', 'germany'): 'blue',
    ('brazil', 'hong kong'): 'blue',
    ('brazil', 'italy'): 'blue',
    ('brazil', 'malaysia'): 'blue',
    ('brazil', 'mexico'): 'blue',
    ('brazil', 'new zealand'): 'blue',
    ('brazil', 'norway'): 'blue',
    ('brazil', 'philippines'): 'blue',
    ('brazil', 'portugal'): 'blue',
    ('brazil', 'south africa'): 'blue',
    ('brazil', 'spain'): 'blue',
    ('brazil', 'sweden'): 'blue',
    ('brazil', 'switzerland'): 'blue',
    ('brazil', 'turkey'): 'blue',
    ('brazil', 'united kingdom'): 'blue',
    ('brazil', 'united states of america'): 'blue',
    ('brazil', 'uruguay'): 'blue',
    ('canada', 'china'): 'green',
    ('canada', 'cyprus'): 'green',
    ('canada', 'denmark'): 'green',
    ('canada', 'france'): 'green',
    ('canada', 'germany'): 'green',
    ('canada', 'india'): 'green',
    ('canada', 'italy'): 'green',
    ('canada', 'japan'): 'green',
    ('canada', 'malaysia'): 'green',
    ('canada', 'mexico'): 'green',
    ('canada', 'netherlands'): 'green',
    ('canada', 'new zealand'): 'green',
    ('canada', 'norway'): 'green',
    ('canada', 'russia'): 'green',
    ('canada', 'south africa'): 'green',
    ('canada', 'south korea'): 'green',
    ('canada', 'spain'): 'green',
    ('canada', 'sweden'): 'green',
    ('canada', 'turkey'): 'green',
    ('canada', 'united kingdom'): 'green',
    ('canada', 'united states of america'): 'green',
    ('chile', 'italy'): 'blue',
    ('chile', 'switzerland'): 'blue',
    ('china', 'cyprus'): 'red',
    ('china', 'denmark'): 'red',
    ('china', 'france'): 'red',
    ('china', 'germany'): 'red',
    ('china', 'hong kong'): 'red',
    ('china', 'italy'): 'red',
    ('china', 'malaysia'): 'red',
    ('china', 'mexico'): 'red',
    ('china', 'norway'): 'red',
    ('china', 'south africa'): 'red',
    ('china', 'sweden'): 'red',
    ('china', 'turkey'): 'red',
    ('china', 'united states of america'): 'red',
    ('cuba', 'spain'): 'blue',
    ('cuba', 'united states of america'): 'blue',
    ('cyprus', 'denmark'): 'red',
    ('cyprus', 'france'): 'red',
    ('cyprus', 'germany'): 'red',
    ('cyprus', 'italy'): 'red',
    ('cyprus', 'malaysia'): 'red',
    ('cyprus', 'mexico'): 'red',
    ('cyprus', 'norway'): 'red',
    ('cyprus', 'south africa'): 'red',
    ('cyprus', 'sweden'): 'red',
    ('cyprus', 'turkey'): 'red',
    ('cyprus', 'united states of america'): 'red',
    ('czech republic', 'italy'): 'blue',
    ('czech republic', 'spain'): 'blue',
    ('czech republic', 'uruguay'): 'blue',
    ('denmark', 'france'): 'red',
    ('denmark', 'germany'): 'red',
    ('denmark', 'italy'): 'red',
    ('denmark', 'malaysia'): 'red',
    ('denmark', 'mexico'): 'red',
    ('denmark', 'norway'): 'red',
    ('denmark', 'south africa'): 'red',
    ('denmark', 'sweden'): 'red',
    ('denmark', 'turkey'): 'red',
    ('denmark', 'united states of america'): 'red',
    ('france', 'germany'): 'green',
    ('france', 'italy'): 'green',
    ('france', 'malaysia'): 'green',
    ('france', 'mexico'): 'green',
    ('france', 'netherlands'): 'green',
    ('france', 'norway'): 'green',
    ('france', 'south africa'): 'green',
    ('france', 'sweden'): 'green',
    ('france', 'turkey'): 'green',
    ('france', 'united kingdom'): 'green',
    ('france', 'united states of america'): 'green',
    ('gabon', 'germany'): 'green',
    ('gabon', 'united kingdom'): 'green',
    ('gabon', 'united states of america'): 'green',
    ('germany', 'hong kong'): 'red',
    ('germany', 'italy'): 'red',
    ('germany', 'japan'): 'red',
    ('germany', 'malaysia'): 'red',
    ('germany', 'mexico'): 'red',
    ('germany', 'netherlands'): 'red',
    ('germany', 'norway'): 'red',
    ('germany', 'south africa'): 'red',
    ('germany', 'spain'): 'red',
    ('germany', 'sweden'): 'red',
    ('germany', 'turkey'): 'red',
    ('germany', 'united kingdom'): 'red',
    ('germany', 'united states of america'): 'red',
    ('germany', 'uruguay'): 'red',
    ('hong kong', 'italy'): 'red',
    ('hong kong', 'mexico'): 'red',
    ('hong kong', 'united states of america'): 'red',
    ('india', 'new zealand'): 'green',
    ('india', 'south korea'): 'green',
    ('indonesia', 'japan'): 'red',
    ('indonesia', 'malaysia'): 'red',
    ('indonesia', 'philippines'): 'red',
    ('indonesia', 'thailand'): 'red',
    ('indonesia', 'vietnam'): 'red',
    ('italy', 'japan'): 'blue',
    ('italy', 'malaysia'): 'blue',
    ('italy', 'mexico'): 'blue',
    ('italy', 'netherlands'): 'blue',
    ('italy', 'new zealand'): 'blue',
    ('italy', 'norway'): 'blue',
    ('italy', 'russia'): 'blue',
    ('italy', 'south africa'): 'blue',
    ('italy', 'spain'): 'blue',
    ('italy', 'sweden'): 'blue',
    ('italy', 'switzerland'): 'blue',
    ('italy', 'turkey'): 'blue',
    ('italy', 'united kingdom'): 'blue',
    ('italy', 'united states of america'): 'blue',
    ('italy', 'uruguay'): 'blue',
    ('japan', 'malaysia'): 'red',
    ('japan', 'netherlands'): 'red',
    ('japan', 'new zealand'): 'red',
    ('japan', 'norway'): 'red',
    ('japan', 'philippines'): 'red',
    ('japan', 'russia'): 'red',
    ('japan', 'spain'): 'red',
    ('japan', 'thailand'): 'red',
    ('japan', 'united kingdom'): 'red',
    ('japan', 'united states of america'): 'red',
    ('japan', 'vietnam'): 'red',
    ('malaysia', 'mexico'): 'red',
    ('malaysia', 'norway'): 'red',
    ('malaysia', 'philippines'): 'red',
    ('malaysia', 'south africa'): 'red',
    ('malaysia', 'sweden'): 'red',
    ('malaysia', 'thailand'): 'red',
    ('malaysia', 'turkey'): 'red',
    ('malaysia', 'united states of america'): 'red',
    ('malaysia', 'vietnam'): 'red',
    ('mexico', 'norway'): 'red',
    ('mexico', 'south africa'): 'red',
    ('mexico', 'sweden'): 'red',
    ('mexico', 'turkey'): 'red',
    ('mexico', 'united states of america'): 'red',
    ('netherlands', 'new zealand'): 'green',
    ('netherlands', 'norway'): 'green',
    ('netherlands', 'russia'): 'green',
    ('netherlands', 'spain'): 'green',
    ('netherlands', 'united kingdom'): 'green',
    ('netherlands', 'united states of america'): 'green',
    ('new zealand', 'norway'): 'green',
    ('new zealand', 'russia'): 'green',
    ('new zealand', 'south korea'): 'green',
    ('new zealand', 'spain'): 'green',
    ('new zealand', 'united kingdom'): 'green',
    ('new zealand', 'united states of america'): 'green',
    ('norway', 'russia'): 'green',
    ('norway', 'south africa'): 'green',
    ('norway', 'sweden'): 'green',
    ('norway', 'turkey'): 'green',
    ('norway', 'united kingdom'): 'green',
    ('norway', 'united states of america'): 'green',
    ('philippines', 'thailand'): 'red',
    ('philippines', 'vietnam'): 'red',
    ('portugal', 'united kingdom'): 'blue',
    ('portugal', 'united states of america'): 'blue',
    ('russia', 'united kingdom'): 'green',
    ('russia', 'united states of america'): 'green',
    ('south africa', 'sweden'): 'red',
    ('south africa', 'turkey'): 'red',
    ('south africa', 'united states of america'): 'red',
    ('spain', 'united kingdom'): 'blue',
    ('spain', 'united states of america'): 'blue',
    ('spain', 'uruguay'): 'blue',
    ('sweden', 'turkey'): 'red',
    ('sweden', 'united states of america'): 'red',
    ('thailand', 'vietnam'): 'red',
    ('turkey', 'united states of america'): 'red',
    ('united kingdom', 'united states of america'): 'green'
}

# Loop through the connection_colors dictionary to plot each connection with its specified color
for connection, color in connection_colors.items():
    country1, country2 = connection
    strength = connections[connection]
    ax.plot([country_centers[country1][1], country_centers[country2][1]], 
            [country_centers[country1][0], country_centers[country2][0]], 
            color=color, linewidth=0.1 + strength * 0.2, alpha=0.8, label=f'{country1.capitalize()} - {country2.capitalize()} ({strength})')
    
# Filter the world map to include only the listed countries
countries_to_plot = ['australia', 'austria', 'china','cyprus', 'denmark', 'germany', 'hong kong', 'indonesia', 'japan', 'malaysia', 'mexico', 'netherlands','philippines', 'south africa', 'sweden', 'thailand', 'turkey', 'vietnam']
filtered_world = world[world['name'].apply(lambda x: x.lower() in countries_to_plot)]

# Fill the filtered countries with red color
filtered_world.plot(ax=ax, color='red', alpha=0.5, edgecolor='black')

# Filter the world map to include only the listed countries2
countries_to_plot = ['canada', 'france', 'gabon', 'india', 'netherlands', 'new zealand', 'norway', 'russia', 'south korea', 'united kingdom']
filtered_world = world[world['name'].apply(lambda x: x.lower() in countries_to_plot)]

# Fill the filtered countries with green color
filtered_world.plot(ax=ax, color='green', alpha=0.5, edgecolor='black')

# Filter the world map to include only the listed countries3
countries_to_plot = ['argentina', 'brazil', 'chile', 'cuba', 'czech republic', 'italy', 'portugal', 'spain', 'switzerland', 'united states of america', 'uruguay']
filtered_world = world[world['name'].apply(lambda x: x.lower() in countries_to_plot)]

# Fill the filtered countries with blue color
filtered_world.plot(ax=ax, color='blue', alpha=0.5, edgecolor='black')
    
# Exibindo o mapa
plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_6456\1471574241.py:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ## Reduced

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Carregando os dados dos contornos dos países
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Excluindo a Antártica
world = world[world['continent'] != 'Antarctica']

# Lista de países e suas coordenadas
country_centers = {
    'argentina': [-38.4161, -63.6167],
    'australia': [-25.2744, 133.7751],
    'brazil': [-14.2350, -51.9253],
    'canada': [56.1304, -106.3468],
    'china': [35.8617, 104.1954],
    'france': [46.6034, 1.8883],
    'germany': [51.1657, 10.4515],
    'india': [20.5937, 78.9629],
    'italy': [41.8719, 12.5674],
    'japan': [36.2048, 138.2529],
    'new zealand': [-40.9006, 174.8860],
    'portugal': [39.3999, -8.2245],
    'south africa': [-30.5595, 22.9375],
    'south korea': [35.9078, 127.7669],
    'spain': [40.4637, -3.7492],
    'united kingdom': [55.3781, -3.4360],
    'united states of america': [37.0902, -95.7129],
    'greece' : [37.983810, 23.727539],
    'colombia' : [4.624335, -74.063644]
    
}

# Lista de conexões e suas forças de conexão
connections = {
    ('argentina', 'australia'): 1,
    ('argentina', 'brazil'): 3,
    ('argentina', 'canada'): 1,
    ('argentina', 'china'): 1,
    ('argentina', 'france'): 1,
    ('argentina', 'germany'): 3,
    ('argentina', 'italy'): 2,
    ('argentina', 'south africa'): 1,
    ('argentina', 'spain'): 2,
    ('argentina', 'united states of america'): 2,
    ('australia', 'brazil'): 4,
    ('australia', 'canada'): 6,
    ('australia', 'china'): 2,
    ('australia', 'france'): 1,
    ('australia', 'germany'): 3,
    ('australia', 'india'): 2,
    ('australia', 'italy'): 4,
    ('australia', 'japan'): 3,
    ('australia', 'new zealand'): 2,
    ('australia', 'south africa'): 1,
    ('australia', 'spain'): 3,
    ('australia', 'united kingdom'): 5,
    ('australia', 'united states of america'): 7,
    ('brazil', 'canada'): 2,
    ('brazil', 'china'): 2,
    ('brazil', 'france'): 2,
    ('brazil', 'germany'): 4,
    ('brazil', 'italy'): 7,
    ('brazil', 'new zealand'): 1,
    ('brazil', 'portugal'): 4,
    ('brazil', 'south africa'): 1,
    ('brazil', 'spain'): 5,
    ('brazil', 'united kingdom'): 2,
    ('brazil', 'united states of america'): 11,
    ('canada', 'china'): 2,
    ('canada', 'france'): 1,
    ('canada', 'germany'): 2,
    ('canada', 'india'): 2,
    ('canada', 'italy'): 3,
    ('canada', 'japan'): 2,
    ('canada', 'new zealand'): 2,
    ('canada', 'south africa'): 1,
    ('canada', 'south korea'): 2,
    ('canada', 'spain'): 3,
    ('canada', 'united kingdom'): 5,
    ('canada', 'united states of america'): 7,
    ('chile', 'italy'): 1,
    ('china', 'france'): 1,
    ('china', 'germany'): 2,
    ('china', 'italy'): 2,
    ('china', 'south africa'): 1,
    ('china', 'united states of america'): 2,
    ('france', 'germany'): 1,
    ('france', 'italy'): 1,
    ('france', 'south africa'): 1,
    ('france', 'united kingdom'): 4,
    ('france', 'united states of america'): 5,
    ('germany', 'italy'): 3,
    ('germany', 'japan'): 1,
    ('germany', 'south africa'): 1,
    ('germany', 'spain'): 1,
    ('germany', 'united kingdom'): 2,
    ('germany', 'united states of america'): 5,
    ('india', 'new zealand'): 1,
    ('india', 'south korea'): 3,
    ('italy', 'japan'): 2,
    ('italy', 'new zealand'): 1,
    ('italy', 'south africa'): 1,
    ('italy', 'spain'): 2,
    ('italy', 'united kingdom'): 2,
    ('italy', 'united states of america'): 5,
    ('japan', 'new zealand'): 1,
    ('japan', 'spain'): 1,
    ('japan', 'united kingdom'): 3,
    ('japan', 'united states of america'): 2,
    ('new zealand', 'south korea'): 1,
    ('new zealand', 'spain'): 1,
    ('new zealand', 'united kingdom'): 2,
    ('new zealand', 'united states of america'): 2,
    ('portugal', 'united kingdom'): 1,
    ('portugal', 'united states of america'): 3,
    ('south africa', 'united states of america'): 2,
    ('spain', 'united kingdom'): 4,
    ('spain', 'united states of america'): 9,
    ('united kingdom', 'united states of america'): 8
}

# Criando um plot
fig, ax = plt.subplots(figsize=(30, 20))
plt.axis('off')
# Plotando os contornos dos países
world.boundary.plot(ax=ax, linewidth=0.5, color='black')

# Dictionary mapping connections to colors
connection_colors = {
    ('argentina', 'australia'): 'blue',
    ('argentina', 'brazil'): 'blue',
    ('argentina', 'canada'): 'blue',
    ('argentina', 'china'): 'blue',
    ('argentina', 'france'): 'blue',
    ('argentina', 'germany'): 'blue',
    ('argentina', 'italy'): 'blue',
    ('argentina', 'south africa'): 'blue',
    ('argentina', 'spain'): 'blue',
    ('argentina', 'united states of america'): 'blue',
    ('australia', 'brazil'): 'red',
    ('australia', 'canada'): 'red',
    ('australia', 'china'): 'red',
    ('australia', 'france'): 'red',
    ('australia', 'germany'): 'red',
    ('australia', 'india'): 'red',
    ('australia', 'italy'): 'red',
    ('australia', 'japan'): 'red',
    ('australia', 'new zealand'): 'red',
    ('australia', 'south africa'): 'red',
    ('australia', 'spain'): 'red',
    ('australia', 'united kingdom'): 'red',
    ('australia', 'united states of america'): 'red',
    ('brazil', 'canada'): 'blue',
    ('brazil', 'china'): 'blue',
    ('brazil', 'france'): 'blue',
    ('brazil', 'germany'): 'blue',
    ('brazil', 'italy'): 'blue',
    ('brazil', 'new zealand'): 'blue',
    ('brazil', 'portugal'): 'blue',
    ('brazil', 'south africa'): 'blue',
    ('brazil', 'spain'): 'blue',
    ('brazil', 'united kingdom'): 'blue',
    ('brazil', 'united states of america'): 'blue',
    ('canada', 'china'): 'green',
    ('canada', 'france'): 'green',
    ('canada', 'germany'): 'green',
    ('canada', 'india'): 'green',
    ('canada', 'italy'): 'green',
    ('canada', 'japan'): 'green',
    ('canada', 'new zealand'): 'green',
    ('canada', 'south africa'): 'green',
    ('canada', 'south korea'): 'green',
    ('canada', 'spain'): 'green',
    ('canada', 'united kingdom'): 'green',
    ('canada', 'united states of america'): 'green',
    ('china', 'france'): 'red',
    ('china', 'germany'): 'red',
    ('china', 'italy'): 'red',
    ('china', 'south africa'): 'red',
    ('china', 'united states of america'): 'red',
    ('france', 'germany'): 'green',
    ('france', 'italy'): 'green',
    ('france', 'south africa'): 'green',
    ('france', 'united kingdom'): 'green',
    ('france', 'united states of america'): 'green',
    ('germany', 'italy'): 'red',
    ('germany', 'japan'): 'red',
    ('germany', 'south africa'): 'red',
    ('germany', 'spain'): 'red',
    ('germany', 'united kingdom'): 'red',
    ('germany', 'united states of america'): 'red',
    ('india', 'new zealand'): 'green',
    ('india', 'south korea'): 'green',
    ('italy', 'japan'): 'blue',
    ('italy', 'new zealand'): 'blue',
    ('italy', 'south africa'): 'blue',
    ('italy', 'spain'): 'blue',
    ('italy', 'united kingdom'): 'blue',
    ('italy', 'united states of america'): 'blue',
    ('japan', 'new zealand'): 'red',
    ('japan', 'spain'): 'red',
    ('japan', 'united kingdom'): 'red',
    ('japan', 'united states of america'): 'red',
    ('new zealand', 'south korea'): 'green',
    ('new zealand', 'spain'): 'green',
    ('new zealand', 'united kingdom'): 'green',
    ('new zealand', 'united states of america'): 'green',
    ('portugal', 'united kingdom'): 'blue',
    ('portugal', 'united states of america'): 'blue',
    ('south africa', 'united states of america'): 'red',
    ('spain', 'united kingdom'): 'blue',
    ('spain', 'united states of america'): 'blue',
    ('united kingdom', 'united states of america'): 'green'
}

# Loop through the connection_colors dictionary to plot each connection with its specified color
for connection, color in connection_colors.items():
    country1, country2 = connection
    strength = connections[connection]
    ax.plot([country_centers[country1][1], country_centers[country2][1]], 
            [country_centers[country1][0], country_centers[country2][0]], 
            color=color, linewidth=0.1 + strength * 0.2, alpha=0.8, label=f'{country1.capitalize()} - {country2.capitalize()} ({strength})')
    
# Filter the world map to include only the listed countries
countries_to_plot = ['australia', 'china', 'germany', 'japan', 'south africa']
filtered_world = world[world['name'].apply(lambda x: x.lower() in countries_to_plot)]

# Fill the filtered countries with red color
filtered_world.plot(ax=ax, color='red', alpha=0.5, edgecolor='black')

# Filter the world map to include only the listed countries2
countries_to_plot = ['canada', 'france', 'india', 'new zealand', 'south korea', 'united kingdom']
filtered_world = world[world['name'].apply(lambda x: x.lower() in countries_to_plot)]

# Fill the filtered countries with green color
filtered_world.plot(ax=ax, color='green', alpha=0.5, edgecolor='black')

# Filter the world map to include only the listed countries3
countries_to_plot = ['argentina', 'brazil', 'italy', 'portugal', 'spain', 'united states of america']
filtered_world = world[world['name'].apply(lambda x: x.lower() in countries_to_plot)]

# Fill the filtered countries with blue color
filtered_world.plot(ax=ax, color='blue', alpha=0.5, edgecolor='black')

# Filter the world map to include only the listed countries
countries_to_plot = ['greece', 'colombia']
filtered_world = world[world['name'].apply(lambda x: x.lower() in countries_to_plot)]

# Fill the filtered countries with red color
filtered_world.plot(ax=ax, color='grey', alpha=0.5, edgecolor='black')
    
# Exibindo o mapa
plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_9048\622641359.py:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
